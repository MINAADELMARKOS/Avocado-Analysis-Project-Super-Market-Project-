# %%
# --- Importing Libraries ---
import datetime
import numpy as np
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objects as go
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import plotly.figure_factory as ff
import datetime as dt
import plotly.io as pio
import dash.dependencies
pio.templates.default = 'simple_white'
# Out:
# C:\Users\Mina\AppData\Local\Temp\ipykernel_8968\2112368676.py:6: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\Mina\AppData\Local\Temp\ipykernel_8968\2112368676.py:7: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
fig__222 = px.histogram(df,x='averageprice')

# %%
fig__222

# %% [markdown]
# ## **HorizontalTable and Chart**

# %%
table_data = [['Years','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],
              ['2015', 1.383449, 1.444481, 1.305244,1.326944,1.365046,1.409444,	1.399074,	1.361981,	1.344685,	1.330611,	1.391968,1.449144],
              ['2016', 1.205023,	1.411111,	1.315995,	1.237106,	1.240185,	1.401333,	1.283056,	1.224213,	1.199722,	1.550023,	1.557093,	1.427870],
              ['2017', 1.502611,	1.698958,	1.363852,	1.214792,	1.277500,	1.564926,	1.545395,	1.398935,	1.532593,	1.517292,	1.752444,	1.840949],
              ['2018',1.387431,	1.398935,	1.398935	,1.318704,	1.387431,	1.698958,	1.517292,	1.336458,	1.517292,	1.698958,	1.387431,	1.517292]
            ]

fig_6 = ff.create_table(table_data, height_constant=60)
# fig_6.show()

# %% [markdown]
# ## **Vertical Table and Chart**

# %%
df_bags_vol=df.groupby(['region','type']).agg({'total_bags':'sum','small_bags':'sum','large_bags':'sum','xlarge_bags':'sum','averageprice':'sum','total_volume':'sum','small_medium_avo':'sum','large_avo':'sum'})
bub_df=df_bags_vol.sort_values(by='total_bags',ascending=False).head(15)
bub_df=bub_df.reset_index()
bub_df.drop(labels=[0],inplace=True)
bub_df
# Out:
#           region          type    total_bags    small_bags    large_bags  \
# 1           West  conventional  3.488013e+08  2.156062e+08  1.323664e+08
# 2     California  conventional  2.378415e+08  2.208116e+08  1.175740e+07
# 3   SouthCentral  conventional  2.220515e+08  1.745251e+08  4.488630e+07
# 4      Northeast  conventional  1.809139e+08  1.588960e+08  2.070849e+07
# 5      Southeast  conventional  1.752940e+08  1.023715e+08  7.040574e+07
# 6     GreatLakes  conventional  1.680633e+08  1.176120e+08  4.405877e+07
# 7     LosAngeles  conventional  1.612009e+08  1.490769e+08  8.048715e+06
# 8       Midsouth  conventional  1.467037e+08  1.271542e+08  1.817115e+07
# 9        TotalUS       organic  8.540751e+07  6.053180e+07  2.487184e+07
# 10        Plains  conventional  7.352393e+07  6.605276e+07  6.358256e+06
# 11       NewYork  conventional  6.428905e+07  5.484327e+07  9.086311e+06
# 12        Denver  conventional  5.562760e+07  1.699719e+07  3.857792e+07
# ...

# %%
fig_5 = px.scatter(bub_df, x="averageprice", y="total_volume",
          size="total_bags", color="region",
                  log_x=True, size_max=60,width=300, title='The Averge Price per Volume per Region')
fig_5.show()

# %% [markdown]
# ### **Mount of Total Vol per year in all months**

# %%
df['year_str']=df['year_dur'].astype('str')

# %%
fig_8 = px.bar(df, x='month_dur', y='total_volume', color='year_str',color_discrete_sequence=px.colors.sequential.RdBu)
fig_8.update_xaxes(title_text = 'Month')
fig_8.update_yaxes(title_text = 'The Total Number Of Avocado')
fig_8.show()

# %%
fig__10=px.scatter(
                df,
                x='total_volume',
                y='small_bags')
fig__10.show()

# %% [markdown]
# # **My Dash App**

# %%
app = JupyterDash(__name__, external_stylesheets=[dbc.themes.FLATLY])

app.layout = dbc.Container([

    dbc.Row([
        dbc.Col(html.H1("Avocado Dashboard",
                        className='text-center text-primary mb-4'),
                width=12)
    ]),

    dbc.Row([
        dbc.Col([
            dcc.Graph(id='graph-1',figure= fig ,style={'width':'100%'})
        ], width={'size':20, 'offset':0, 'order':1},
    
        )     
    ], justify='center'),
    
    dbc.Row([
        dbc.Col([
            dcc.Graph(id='graph-2',figure= fig_5 ,style={'width':'90%'})
        ], width={'size':7, 'offset':0, 'order':1},
    
        ),

        dbc.Col([
            dcc.Graph(id='graph-3',figure= fig_12 ,style={'width':'100%'})
        ], width={'size':5, 'offset':0, 'order':2},

        ),
        ], justify='around'),
    dbc.Row([
        dbc.Col([
            dcc.Graph(id='graph-4',figure= fig_8 ,style={'width':'100%'})
        ], width={'size':12, 'offset':0, 'order':1},
    
        )
        ], justify='around'),    

])


app.run_server(mode='external')
# Out:
# Dash app running on http://127.0.0.1:8050/
